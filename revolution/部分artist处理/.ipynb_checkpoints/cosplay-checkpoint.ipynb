# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.utils import shuffle
from tqdm import tqdm
from sklearn.utils import shuffle
import math
import sys
import os

# %%
dataFrame_full_artist = pd.read_excel("full_music_data.xlsx")
dataFrame_full_artist.sort_values(by=["artists_id", 'year'], ascending=True)
# Out:
#                                  artist_names        artists_id  danceability  \
# 30809                             ['Emarosa']         [1000177]         0.386
# 30808                             ['Emarosa']         [1000177]         0.334
# 5106                       ['3OH!3', 'Kesha']  [1000302, 80358]         0.682
# 5108                                ['3OH!3']         [1000302]         0.590
# 5109                                ['3OH!3']         [1000302]         0.851
# ...                                       ...               ...           ...
# 10882                         ['Beach House']          [998969]         0.509
# 10890                         ['Beach House']          [998969]         0.490
# 13526  ['Bingo Players', 'Far East Movement']  [999790, 870646]         0.802
# 13527                       ['Bingo Players']          [999790]         0.744
# 13528                       ['Bingo Players']          [999790]         0.744
#
#        energy  valence    tempo  loudness  mode  key  acousticness  \
# 30809   0.941    0.483   90.913    -2.168     1    6      0.000550
# 30808   0.924    0.359  170.159    -3.805     0    8      0.004440
# 5106    0.889    0.827  138.021    -4.166     1    0      0.005640
# 5108    0.813    0.517  161.868    -3.543     0    5      0.004160
# 5109    0.633    0.513  139.944    -5.052     1   10      0.000905
# ...       ...      ...      ...       ...   ...  ...           ...
# 10882   0.790    0.625  147.073    -7.105     0    0      0.218000
# 10890   0.464    0.142  104.896    -7.478     1    1      0.381000
# 13526   0.981    0.804  127.974    -2.708     1    7      0.020400
# 13527   0.957    0.529  127.991    -4.800     1    7      0.001520
# 13528   0.483    0.298  125.953    -7.712     0    4      0.095700
#
#        instrumentalness  liveness  speechiness  explicit  duration_ms  \
# 30809          0.000000    0.1400       0.0515         0       273653
# 30808          0.000000    0.1360       0.2760         0       228987
# 5106           0.000000    0.3600       0.0804         0       192440
# 5108           0.000000    0.7480       0.3420         1       199600
# 5109           0.000003    0.1160       0.1100         0       185533
# ...                 ...       ...          ...       ...          ...
# 10882          0.125000    0.1440       0.0293         0       320467
# 10890          0.894000    0.0555       0.0284         0       368547
# 13526          0.000004    0.2560       0.0658         0       166760
# 13527          0.884000    0.3520       0.0519         0       287184
# 13528          0.032200    0.4080       0.0408         0       167845
#
#        popularity  year release_date        song_title (censored) Unnamed: 19
# 30809          48  2008     7/8/2008    The Past Should Stay Dead         NaN
# 30808          47  2010    6/28/2010  A Toast to the future kids!         NaN
# 5106           63  2010    6/25/2010  My First Kiss (feat. Ke$ha)         NaN
# 5108           45  2008     7/7/2008                      RICHMAN         NaN
# 5109           45  2008     7/7/2008                   STARSTRUKK         NaN
# ...           ...   ...          ...                          ...         ...
# 10882          68  2015    8/28/2015                   ***** Song         NaN
# 10890          55  2015    8/28/2015                          PPP         NaN
# 13526          51  2013     1/1/2013              Get Up (Rattle)         NaN
# 13527          59  2011   10/31/2011                       Rattle         NaN
# 13528          47  2011    10/4/2011          Cry (Just a Little)         NaN
#
# [98340 rows x 20 columns]

# %%
# read_dictionary
name_dic = open("name_to_id_dictionary.txt", "r")
string = ""
line = 1
while line:
    line = name_dic.readline()
    string += line
name_dic = eval(string)
person_num = len(name_dic)
print("person_num = ",person_num)
# Out:
# person_num =  5641

# %%
for idx, row in tqdm(dataFrame_full_artist.iterrows(),):
    m = row["artists_id"].find(',')
    if m != -1:
        Id=int(row["artists_id"][1:m])
    else:
        Id=int(row["artists_id"][1:-1])
    dataFrame_full_artist["artists_id"][idx] = Id
dataFrame_full_artist
# Out:
# 0it [00:00, ?it/s]<ipython-input-4-31702c7ee6ec>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame_full_artist["artists_id"][idx] = Id
# 98340it [01:21, 1210.40it/s]
#                 artist_names artists_id  danceability  energy  valence  \
# 0      ["Fat Freddy's Drop"]     178301         0.600   0.365    0.131
# 1      ["Fat Freddy's Drop"]     178301         0.874   0.326    0.179
# 2      ["Fat Freddy's Drop"]     178301         0.670   0.531    0.336
# 3       ["Alexander O'Neal"]     625201         0.761   0.702    0.850
# 4       ["Alexander O'Neal"]     625201         0.661   0.828    0.902
# ...                      ...        ...           ...     ...      ...
# 98335             ['ZZ Top']     690254         0.276   0.892    0.715
# 98336             ['ZZ Top']     690254         0.700   0.592    0.906
# 98337             ['ZZ Top']     690254         0.709   0.709    0.863
# 98338             ['ZZ Top']     690254         0.552   0.651    0.533
# 98339             ['ZZ Top']     690254         0.546   0.864    0.863
#
#          tempo  loudness  mode  key  acousticness  instrumentalness  liveness  \
# 0      130.046   -13.083     0    9       0.06720          0.585000    0.0921
# 1      119.620   -13.302     0   11       0.01360          0.148000    0.0993
# 2      139.385    -8.267     0    9       0.01560          0.345000    0.3060
# 3      104.773    -8.523     1    7       0.10800          0.000031    0.0935
# 4      115.078   -12.673     0   11       0.27600          0.000001    0.2870
# ...        ...       ...   ...  ...           ...               ...       ...
# 98335   80.475    -7.035     1   11       0.40900          0.000000    0.7140
# 98336  109.847   -10.434     1   11       0.10800          0.018400    0.1180
# 98337  111.544   -12.023     1    2       0.11800          0.000011    0.1250
# 98338  161.548   -10.624     0    4       0.00494          0.034900    0.1320
# 98339  145.652    -7.632     1    7       0.09080          0.008140    0.2770
#
#        speechiness  explicit  duration_ms  popularity  year release_date  \
# 0           0.0498         0       437200          54  2005         2005
# 1           0.1310         0       581008          53  2005         2005
# 2           0.0377         0       431293          55  2009     8/7/2009
# 3           0.0389         0       304427          34  1991     1/1/1991
# 4           0.0390         0       264933          37  1987    7/29/1987
# ...            ...       ...          ...         ...   ...          ...
# 98335       0.0893         0       115973          33  1975    4/18/1975
# 98336       0.0681         0       263627          32  1976   11/29/1976
# 98337       0.0370         0       158400          31  1987         1987
# 98338       0.2290         0       232533          43  1992    4/13/1992
# 98339       0.0393         0       137240          43  2005    7/19/2005
#
#                       song_title (censored) Unnamed: 19
# 0                                     Ernie         NaN
# 1                             Wandering Eye         NaN
# 2                                  The Raft         NaN
# 3                              All True Man         NaN
# 4      (What Can I Say) To Make You Love Me         NaN
# ...                                     ...         ...
# 98335        Jailhouse Rock - **** Remaster         NaN
# 98336                        It's Only Love         NaN
# 98337                              Balinese         NaN
# 98338             La Grange - **** Remaster         NaN
# 98339                                  ****         NaN
#
# [98340 rows x 20 columns]

# %%
full_music_data = {"danceability":[0.5263203874313606,0.16403205144827973],
                    "energy":[0.5342478371079926,0.26447724025183267],
                    "valence":[0.5332812944885094,0.2585376133654879],
                    "tempo":[118.96853772625585,29.925255322835987],
                    "loudness":[-10.755944010575554,5.067612837357291],
                    "acousticness":[0.4190568774831198,0.35370999027336875],
                    "instrumentalness":[0.1255745396816148,0.2724918312399652],
                    "liveness":[0.20700085794183445,0.18610339608517842],
                    "speechiness":[0.06380584502745576,0.07610388534934469],
                    "explicit":[0.037085621313809235,0.18897163280656168],
                    "duration_ms":[238590.92141549726,108823.17603973577],
                    "mode":[0.7219951189749847,0.4480158112737567],
                    "popularity":[35.69332926581249,17.262527298425432],}
print(len(full_music_data))
# Out:
# 13

# %%
extractedData = pd.read_csv("extractedData.csv")
extractedData
# Out:
#        Unnamed: 0  artists_id  danceability    energy   valence     tempo  \
# 0           77723          74      0.315058  1.250588 -0.179012 -0.061972
# 1           68873         335     -0.355543  0.104932 -0.534859  0.270222
# 2           68876         335     -0.629879 -0.034966  0.416646  1.090031
# 3           68874         335     -0.623783  0.437664  0.849852  0.241885
# 4           68878         335      0.967370 -0.859234  1.155417  0.335017
# ...           ...         ...           ...       ...       ...       ...
# 98335       60481     3661296      0.717418  1.156062  1.190228 -0.666077
# 98336       60483     3661296      1.613585  0.898951 -0.221559  0.234700
# 98337       60480     3661296      0.851539  1.042631  1.074191 -0.666512
# 98338       73261     3661738     -0.215326 -0.484911 -0.983537  0.704504
# 98339       93614     3670556      1.406308  0.887608  0.931078  0.172445
#
#        loudness  acousticness  instrumentalness  liveness  speechiness  \
# 0      0.728932     -1.110110         -0.454049  0.848986    -0.233968
# 1     -1.010151     -1.156193         -0.459689 -0.445993    -0.260247
# 2     -1.153809     -1.171516         -0.449425 -0.558834    -0.343029
# 3     -1.071916     -1.183268          2.669531 -0.515847     0.048541
# 4     -1.651479     -1.128769         -0.447076 -0.531967     0.076135
# ...         ...           ...               ...       ...          ...
# 98335  1.173717     -0.726745         -0.460838 -0.790425    -0.289155
# 98336  1.389401     -1.019357         -0.459950 -0.695317    -0.320691
# 98337  1.219893     -0.755016         -0.460838 -0.782903    -0.236596
# 98338 -0.503799      1.133536          0.438272 -0.456740    -0.473114
# 98339  0.881074      0.279730         -0.460838  0.682412     0.465077
#
#        explicit  duration_ms      mode  popularity  year  key
# 0       5.09555    -1.086569  0.620525          26  1983    9
# 1      -0.19625    -0.438307  0.620525          33  1992    1
# 2      -0.19625    -0.371161  0.620525          31  1992   11
# 3      -0.19625    -0.872277  0.620525          38  1993    7
# 4      -0.19625    -0.388556 -1.611539          41  1993    9
# ...         ...          ...       ...         ...   ...  ...
# 98335  -0.19625    -0.348987  0.620525          53  2012    8
# 98336  -0.19625    -0.199019  0.620525          54  2012   10
# 98337  -0.19625    -0.352663  0.620525          58  2013    8
# 98338  -0.19625     0.472134  0.620525          58  2015    5
# 98339   5.09555    -0.230198 -1.611539          60  2017    5
#
# [98340 rows x 17 columns]

# %%
artist_number_df = extractedData["artists_id"].value_counts()
art_number = artist_number_df.values
index = artist_number_df.index.values
print("art_number = ", art_number)  # 对应id的数目
print("index = ", index)  # 艺术家的id
artist_dict = {}
for i in range(len(art_number)):
    artist_dict[index[i]] = art_number[i]

index_sorted = np.sort(index)
artist_num =[]
for i in range(len(index_sorted)):
    artist_num.append([index_sorted[i],artist_dict[index_sorted[i]]])
artist_num = np.array(artist_num).T[-1].astype(int)
artist_position = np.cumsum(artist_num)
print("artist_num = \n", artist_num)
print("artist_position = \n", artist_position)
# Out:
# art_number =  [938 692 684 ...   1   1   1]
# index =  [ 26350 792507  79016 ... 562144 830375  26637]
# artist_num =
#  [ 1 16 11 ...  9  1  1]
# artist_position =
#  [    1    17    28 ... 98338 98339 98340]

# %%
# 获得位置范围的range列表
pos = 0
range_list = []
for i in range(len(artist_position)):
    range_list.append([pos, artist_position[i]])
    pos = artist_position[i]
print(len(range_list))
# print(range_list)
# Out:
# 5641

# %%
for _range_ in tqdm(range_list):
    for i in range(_range_[0],_range_[1]):
        extractedData.loc[i,"num"] = _range_[1] - _range_[0]
extractedData = extractedData[extractedData["num"] > 20]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5641/5641 [00:25<00:00, 218.19it/s]

# %%
extractedData.to_csv("important_artist_data.csv")
extractedData
# Out:
#        Unnamed: 0  artists_id  danceability    energy   valence     tempo  \
# 33          77617        1098     -1.026143  1.352677 -0.623821  0.278777
# 34          77627        1098     -1.574817  1.190092 -0.132597  1.888988
# 35          77640        1098     -1.910117  0.880046 -0.565803  1.847619
# 36          77642        1098      0.254094  0.328014 -1.207876  0.187850
# 37          77646        1098     -1.708937  1.602225 -1.432214  0.452108
# ...           ...         ...           ...       ...       ...       ...
# 98212       12367     3475903      2.003752 -0.420633  0.149760  0.035136
# 98213       12368     3475903      1.272188 -1.131469 -0.275710 -1.888790
# 98214       12371     3475903     -2.275899 -1.498230 -1.868128 -1.492069
# 98215       12374     3475903      1.034430 -0.764708 -1.819779  1.041310
# 98216       12360     3475903     -0.892023 -1.191966 -1.862713 -1.518167
#
#        loudness  acousticness  instrumentalness  liveness  speechiness  \
# 33     0.037285     -1.168406         -0.329825  0.042982    -0.068404
# 34     0.241720     -1.171912         -0.458731  1.826937    -0.006647
# 35     0.111284     -0.387484         -0.460346 -0.643195    -0.102568
# 36    -0.242532     -0.336595          0.027250 -0.548087    -0.356169
# 37     0.293421     -1.146297         -0.181930 -0.462113     0.031459
# ...         ...           ...               ...       ...          ...
# 98212 -0.846169      0.862128          1.260315 -0.630837    -0.069718
# 98213 -0.489985      0.788621         -0.438672 -0.537340     3.300675
# 98214 -2.194535      1.181598          1.557571  0.252543    -0.177466
# 98215 -0.410066      1.226833          1.128201 -0.656629    -0.279957
# 98216 -0.496695      1.407772         -0.422672 -0.667913    -0.367995
#
#        explicit  duration_ms      mode  popularity  year  key   num
# 33     -0.19625    -0.134327  0.620525          30  1989    9  62.0
# 34      5.09555     0.114397 -1.611539          28  1989    6  62.0
# 35     -0.19625     0.097122 -1.611539          26  1989    9  62.0
# 36     -0.19625     0.207760 -1.611539          25  1989    4  62.0
# 37     -0.19625    -0.199019  0.620525          24  1989    9  62.0
# ...         ...          ...       ...         ...   ...  ...   ...
# 98212  -0.19625    -0.755537 -1.611539          79  2019    5  41.0
# 98213  -0.19625    -0.600873  0.620525          77  2019    3  41.0
# 98214  -0.19625    -1.095180 -1.611539          74  2019    6  41.0
# 98215  -0.19625     0.293403  0.620525          71  2019    6  41.0
# 98216  -0.19625     0.033762 -1.611539          84  2020    4  41.0
#
# [74146 rows x 18 columns]
