# %% [markdown]
# # 数据读取部分

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.utils import shuffle
from tqdm import tqdm
import math
import sys
import os

# %%
print("本地路径 = ", sys.argv[0], "\n")

path1 = os.getcwd() #获取当前工作目录路径
path2 = os.path.abspath('.') #获取当前工作目录路径
path3 = os.path.abspath('test.txt') #获取当前目录文件下的工作目录路径
path4 = os.path.abspath('..') #获取当前工作的父目录 ！注意是父目录路径
path5 = os.path.abspath(os.curdir) #获取当前工作目录路径

print("当前的代码绝对路径 = ",path1)
print("获取当前工作目录路径 = ",path2)
print("获取当前目录文件下的工作目录路径 = ",path3)
print("获取当前工作的父目录 = ",path4)
print("获取当前工作目录路径 = ",path5)

def show_file(file_dir):
    
    print("\n\nFiles in your current working directory:")
    dirlist = os.listdir(os.getcwd())
    for i, file in enumerate(dirlist):
        print(f"  [{i}] ", file)
        
show_file(os.getcwd())
# Out:
# 本地路径 =  d:\python\lib\site-packages\ipykernel_launcher.py
#
# 当前的代码绝对路径 =  C:\Users\程琪皓\Desktop\作家按照年份处理数据
# 获取当前工作目录路径 =  C:\Users\程琪皓\Desktop\作家按照年份处理数据
# 获取当前目录文件下的工作目录路径 =  C:\Users\程琪皓\Desktop\作家按照年份处理数据\test.txt
# 获取当前工作的父目录 =  C:\Users\程琪皓\Desktop
# 获取当前工作目录路径 =  C:\Users\程琪皓\Desktop\作家按照年份处理数据
#
#
# Files in your current working directory:
#   [0]  .ipynb_checkpoints
#   [1]  data_analysis.ipynb
#   [2]  full_music_data.csv
#   [3]  full_music_data.xlsx
#   [4]  genre
#   [5]  genre_key_year
#   [6]  genre_year
#   [7]  GMM.ipynb
#   [8]  influence_data.csv
#   [9]  influence_data.xlsx
#   [10]  NN.ipynb
#   [11]  Sort_full_music_data_by_genre.ipynb
#   [12]  Sort_genre_by_year.ipynb
#   [13]  五度循环文献.pdf

# %% [markdown]
# # Read in the file

# %%
influence_data = pd.read_csv("influence_data.csv")
influence_data.head()
# Out:
#    influencer_id influencer_name influencer_main_genre  \
# 0           1163   Serge Chaloff                  Jazz
# 1           2130   Alfred Newman        Stage & Screen
# 2           2130   Alfred Newman        Stage & Screen
# 3           2130   Alfred Newman        Stage & Screen
# 4           2130   Alfred Newman        Stage & Screen
#
#    influencer_active_start  follower_id    follower_name follower_main_genre  \
# 0                     1930       542549   Gerry Mulligan                Jazz
# 1                     1930       678009    Henry Mancini      Easy Listening
# 2                     1930       394806     Randy Newman            Pop/Rock
# 3                     1930       330634  Jerry Goldsmith      Stage & Screen
# 4                     1930       327765       John Barry      Stage & Screen
#
#    follower_active_start
# 0                   1940
# 1                   1940
# 2                   1960
# 3                   1950
# 4                   1950

# %%
dataFrame_full_artist = pd.read_excel("full_music_data.xlsx")
dataFrame_full_artist.head()
# Out:
#             artist_names artists_id  danceability  energy  valence    tempo  \
# 0  ["Fat Freddy's Drop"]   [178301]         0.600   0.365    0.131  130.046
# 1  ["Fat Freddy's Drop"]   [178301]         0.874   0.326    0.179  119.620
# 2  ["Fat Freddy's Drop"]   [178301]         0.670   0.531    0.336  139.385
# 3   ["Alexander O'Neal"]   [625201]         0.761   0.702    0.850  104.773
# 4   ["Alexander O'Neal"]   [625201]         0.661   0.828    0.902  115.078
#
#    loudness  mode  key  acousticness  instrumentalness  liveness  speechiness  \
# 0   -13.083     0    9        0.0672          0.585000    0.0921       0.0498
# 1   -13.302     0   11        0.0136          0.148000    0.0993       0.1310
# 2    -8.267     0    9        0.0156          0.345000    0.3060       0.0377
# 3    -8.523     1    7        0.1080          0.000031    0.0935       0.0389
# 4   -12.673     0   11        0.2760          0.000001    0.2870       0.0390
#
#    explicit  duration_ms  popularity  year release_date  \
# 0         0       437200          54  2005         2005
# 1         0       581008          53  2005         2005
# 2         0       431293          55  2009     8/7/2009
# 3         0       304427          34  1991     1/1/1991
# 4         0       264933          37  1987    7/29/1987
#
#                   song_title (censored) Unnamed: 19
# 0                                 Ernie         NaN
# 1                         Wandering Eye         NaN
# 2                              The Raft         NaN
# 3                          All True Man         NaN
# 4  (What Can I Say) To Make You Love Me         NaN

# %%
for collumn in ["danceability","energy","valence","tempo", "loudness","acousticness","instrumentalness","liveness",
                                     "speechiness","explicit","duration_ms", "mode", "popularity"]:
    information = dataFrame_full_artist.loc[:,collumn].values
    print(f"{collumn}:[{information.mean()},{np.sqrt(information.var())}]")
# Out:
# danceability:[0.5263203874313606,0.16403205144827973]
# energy:[0.5342478371079926,0.26447724025183267]
# valence:[0.5332812944885094,0.2585376133654879]
# tempo:[118.96853772625585,29.925255322835987]
# loudness:[-10.755944010575554,5.067612837357291]
# acousticness:[0.4190568774831198,0.35370999027336875]
# instrumentalness:[0.1255745396816148,0.2724918312399652]
# liveness:[0.20700085794183445,0.18610339608517842]
# speechiness:[0.06380584502745576,0.07610388534934469]
# explicit:[0.037085621313809235,0.18897163280656168]
# duration_ms:[238590.92141549726,108823.17603973577]
# mode:[0.7219951189749847,0.4480158112737567]
# popularity:[35.69332926581249,17.262527298425432]

# %%
# dataFrame_artist.dtypes
sample_num = dataFrame_full_artist.index
for i in sample_num:
    try:
        int(dataFrame_full_artist["instrumentalness"][i])
    except:
        print(type(dataFrame_full_artist["instrumentalness"][i]))
        print(i)

# %%
dataFrame_full_artist.dtypes
# Out:
# artist_names              object
# artists_id                object
# danceability             float64
# energy                   float64
# valence                  float64
# tempo                    float64
# loudness                 float64
# mode                       int64
# key                        int64
# acousticness             float64
# instrumentalness         float64
# liveness                 float64
# speechiness              float64
# explicit                   int64
# duration_ms                int64
# popularity                 int64
# year                       int64
# release_date              object
# song_title (censored)     object
# Unnamed: 19               object
# dtype: object

# %% [markdown]
# # 首先从influence data当中获得一个 artists 到genra 的映射

# %%
influence_col = influence_data.loc[:,["influencer_id","influencer_name","influencer_main_genre","influencer_active_start"]]
influence_col.columns =["id","name","genre","year"]
influence_col.head()
follower_col = influence_data.loc[:,["follower_id","follower_name","follower_main_genre","follower_active_start"]]
follower_col.columns =["id","name","genre","year"]
person_col = pd.concat([influence_col,follower_col])

# per_col.index=range(85540)
person_col.shape
person_col.head()
# Out:
#      id           name           genre  year
# 0  1163  Serge Chaloff            Jazz  1930
# 1  2130  Alfred Newman  Stage & Screen  1930
# 2  2130  Alfred Newman  Stage & Screen  1930
# 3  2130  Alfred Newman  Stage & Screen  1930
# 4  2130  Alfred Newman  Stage & Screen  1930

# %%
per_map=person_col.drop_duplicates(["id"])
per_map.head()
# Out:
#        id           name           genre  year
# 0    1163  Serge Chaloff            Jazz  1930
# 1    2130  Alfred Newman  Stage & Screen  1930
# 7    3413    Allan Jones           Vocal  1930
# 8    3829  T-Bone Walker           Blues  1930
# 56  11028  Frank Loesser  Stage & Screen  1930

# %%
def getGenre(id):
    try:
        return per_map[per_map.id==id].iloc[0,2]
    except:
#         print(id)
        return "Unknown"
getGenre(12138)
# Out:
# 'Unknown'

# %% [markdown]
# # 其次将artist表当中的artist添加流派一列，并且按照流派进行区分

# %% [markdown]
# # 在artist后面添加一列genre

# %% [markdown]
# ## 建立一个字典genre_map,将数字对应到不同的流派

# %%
genre_map=influence_data.drop_duplicates(["follower_main_genre"])["follower_main_genre"]
genre_map.index=range(20)
genre_map=genre_map.to_dict()
genre_map # genre对应的字典
# Out:
# {0: 'Jazz',
#  1: 'Easy Listening',
#  2: 'Pop/Rock',
#  3: 'Stage & Screen',
#  4: 'Vocal',
#  5: 'R&B;',
#  6: 'Blues',
#  7: 'Folk',
#  8: 'Religious',
#  9: 'International',
#  10: 'Country',
#  11: 'Latin',
#  12: 'Classical',
#  13: 'Reggae',
#  14: 'Comedy/Spoken',
#  15: 'Avant-Garde',
#  16: 'Electronic',
#  17: "Children's",
#  18: 'New Age',
#  19: 'Unknown'}

# %% [markdown]
# # 建立一个字典re_genre_map，将流派对应回数字

# %%
re_genre_map={}
for i,key in enumerate(genre_map):
    re_genre_map[genre_map[key]]=key
re_genre_map
# Out:
# {'Jazz': 0,
#  'Easy Listening': 1,
#  'Pop/Rock': 2,
#  'Stage & Screen': 3,
#  'Vocal': 4,
#  'R&B;': 5,
#  'Blues': 6,
#  'Folk': 7,
#  'Religious': 8,
#  'International': 9,
#  'Country': 10,
#  'Latin': 11,
#  'Classical': 12,
#  'Reggae': 13,
#  'Comedy/Spoken': 14,
#  'Avant-Garde': 15,
#  'Electronic': 16,
#  "Children's": 17,
#  'New Age': 18,
#  'Unknown': 19}

# %%
dataFrame_full_artist.head()
# Out:
#             artist_names artists_id  danceability  energy  valence    tempo  \
# 0  ["Fat Freddy's Drop"]   [178301]         0.600   0.365    0.131  130.046
# 1  ["Fat Freddy's Drop"]   [178301]         0.874   0.326    0.179  119.620
# 2  ["Fat Freddy's Drop"]   [178301]         0.670   0.531    0.336  139.385
# 3   ["Alexander O'Neal"]   [625201]         0.761   0.702    0.850  104.773
# 4   ["Alexander O'Neal"]   [625201]         0.661   0.828    0.902  115.078
#
#    loudness  mode  key  acousticness  instrumentalness  liveness  speechiness  \
# 0   -13.083     0    9        0.0672          0.585000    0.0921       0.0498
# 1   -13.302     0   11        0.0136          0.148000    0.0993       0.1310
# 2    -8.267     0    9        0.0156          0.345000    0.3060       0.0377
# 3    -8.523     1    7        0.1080          0.000031    0.0935       0.0389
# 4   -12.673     0   11        0.2760          0.000001    0.2870       0.0390
#
#    explicit  duration_ms  popularity  year release_date  \
# 0         0       437200          54  2005         2005
# 1         0       581008          53  2005         2005
# 2         0       431293          55  2009     8/7/2009
# 3         0       304427          34  1991     1/1/1991
# 4         0       264933          37  1987    7/29/1987
#
#                   song_title (censored) Unnamed: 19
# 0                                 Ernie         NaN
# 1                         Wandering Eye         NaN
# 2                              The Raft         NaN
# 3                          All True Man         NaN
# 4  (What Can I Say) To Make You Love Me         NaN

# %%
tmp=0
for i,r in tqdm(dataFrame_full_artist.iterrows(),):
    m=r["artists_id"].find(',')
    Id=0
    if m!=-1:
        Id=int(r["artists_id"][1:m])
    else:
        Id=int(r["artists_id"][1:-1])
    dataFrame_full_artist.loc[i,"genre"]=getGenre(Id)
    if dataFrame_full_artist.loc[i,"genre"]!=-1:
        dataFrame_full_artist.loc[i,"genre_id"]=re_genre_map[dataFrame_full_artist.loc[i,"genre"]]
    else:
        dataFrame_full_artist.loc[i,"genre_id"]=-1

dataFrame_full_artist
# Out:
# 98340it [04:06, 398.53it/s]
#                 artist_names artists_id  danceability  energy  valence  \
# 0      ["Fat Freddy's Drop"]   [178301]         0.600   0.365    0.131
# 1      ["Fat Freddy's Drop"]   [178301]         0.874   0.326    0.179
# 2      ["Fat Freddy's Drop"]   [178301]         0.670   0.531    0.336
# 3       ["Alexander O'Neal"]   [625201]         0.761   0.702    0.850
# 4       ["Alexander O'Neal"]   [625201]         0.661   0.828    0.902
# ...                      ...        ...           ...     ...      ...
# 98335             ['ZZ Top']   [690254]         0.276   0.892    0.715
# 98336             ['ZZ Top']   [690254]         0.700   0.592    0.906
# 98337             ['ZZ Top']   [690254]         0.709   0.709    0.863
# 98338             ['ZZ Top']   [690254]         0.552   0.651    0.533
# 98339             ['ZZ Top']   [690254]         0.546   0.864    0.863
#
#          tempo  loudness  mode  key  acousticness  ...  speechiness  explicit  \
# 0      130.046   -13.083     0    9       0.06720  ...       0.0498         0
# 1      119.620   -13.302     0   11       0.01360  ...       0.1310         0
# 2      139.385    -8.267     0    9       0.01560  ...       0.0377         0
# 3      104.773    -8.523     1    7       0.10800  ...       0.0389         0
# 4      115.078   -12.673     0   11       0.27600  ...       0.0390         0
# ...        ...       ...   ...  ...           ...  ...          ...       ...
# 98335   80.475    -7.035     1   11       0.40900  ...       0.0893         0
# 98336  109.847   -10.434     1   11       0.10800  ...       0.0681         0
# 98337  111.544   -12.023     1    2       0.11800  ...       0.0370         0
# 98338  161.548   -10.624     0    4       0.00494  ...       0.2290         0
# 98339  145.652    -7.632     1    7       0.09080  ...       0.0393         0
#
#        duration_ms  popularity  year  release_date  \
# 0           437200          54  2005          2005
# 1           581008          53  2005          2005
# 2           431293          55  2009      8/7/2009
# 3           304427          34  1991      1/1/1991
# 4           264933          37  1987     7/29/1987
# ...            ...         ...   ...           ...
# 98335       115973          33  1975     4/18/1975
# 98336       263627          32  1976    11/29/1976
# 98337       158400          31  1987          1987
# 98338       232533          43  1992     4/13/1992
# 98339       137240          43  2005     7/19/2005
#
#                       song_title (censored) Unnamed: 19       genre genre_id
# 0                                     Ernie         NaN  Electronic     16.0
# 1                             Wandering Eye         NaN  Electronic     16.0
# 2                                  The Raft         NaN  Electronic     16.0
# 3                              All True Man         NaN        R&B;      5.0
# 4      (What Can I Say) To Make You Love Me         NaN        R&B;      5.0
# ...                                     ...         ...         ...      ...
# 98335        Jailhouse Rock - **** Remaster         NaN    Pop/Rock      2.0
# 98336                        It's Only Love         NaN    Pop/Rock      2.0
# 98337                              Balinese         NaN    Pop/Rock      2.0
# 98338             La Grange - **** Remaster         NaN    Pop/Rock      2.0
# 98339                                  ****         NaN    Pop/Rock      2.0
#
# [98340 rows x 22 columns]

# %%
dataFrame_full_artist = dataFrame_full_artist.sort_values(by=['genre_id', 'year', 'artists_id'], ascending=True)
dataFrame_full_artist
# Out:
#                            artist_names        artists_id  danceability  \
# 40098                 ['Hot Lips Page']          [825032]         0.626
# 17637                 ['Bunny Berigan']          [639789]         0.531
# 17638                 ['Bunny Berigan']          [639789]         0.636
# 28638      ['Eddie "Cleanhead" Vinson']          [137137]         0.597
# 39191  ['Harry James', 'Helen Forrest']  [950571, 673360]         0.283
# ...                                 ...               ...           ...
# 20420              ['Childish Gambino']         [2487188]         0.798
# 1811                  ['Glass Animals']         [2984484]         0.854
# 1814                  ['Glass Animals']         [2984484]         0.253
# 39330               ['Hayley Williams']          [364537]         0.737
# 39331               ['Hayley Williams']          [364537]         0.790
#
#        energy  valence    tempo  loudness  mode  key  acousticness  ...  \
# 40098   0.452    0.835  125.293   -12.341     0    7         0.968  ...
# 17637   0.170    0.805  165.165   -14.500     1    5         0.991  ...
# 17638   0.468    0.922  109.831   -12.714     1    5         0.921  ...
# 28638   0.194    0.625   73.699   -11.920     1    5         0.964  ...
# 39191   0.223    0.383   75.249    -9.699     1    0         0.941  ...
# ...       ...      ...      ...       ...   ...  ...           ...  ...
# 20420   0.559    0.604  102.018   -10.868     1    5         0.286  ...
# 1811    0.671    0.631  107.994    -7.158     1    7         0.019  ...
# 1814    0.352    0.099  141.970   -11.509     1    8         0.883  ...
# 39330   0.787    0.590   90.014    -4.587     1    7         0.121  ...
# 39331   0.599    0.362  109.978    -7.417     1    7         0.218  ...
#
#        speechiness  explicit  duration_ms  popularity  year  release_date  \
# 40098       0.0698         0       200067           0  1924          1924
# 17637       0.0771         0       197787          27  1925          1925
# 17638       0.0575         0       188040           6  1926          1926
# 28638       0.0883         0       161067           0  1927          1927
# 39191       0.0304         0       203773           3  1927          1927
# ...            ...       ...          ...         ...   ...           ...
# 20420       0.0592         1       236507          63  2020     3/22/2020
# 1811        0.0543         0       234372          69  2020     2/19/2020
# 1814        0.0357         0       203492          68  2020      5/1/2020
# 39330       0.0525         0       199413          66  2020      5/8/2020
# 39331       0.0431         1       266116          65  2020      5/8/2020
#
#              song_title (censored) Unnamed: 19    genre genre_id
# 40098                 Jump For Joy         NaN     Jazz      0.0
# 17637                        Marie         NaN     Jazz      0.0
# 17638             *********** Rose         NaN     Jazz      0.0
# 28638  When My Baby Left Me - Live         NaN     Jazz      0.0
# 39191  It's Been a Long, Long Time         NaN     Jazz      0.0
# ...                            ...         ...      ...      ...
# 20420                        *****         NaN  Unknown     19.0
# 1811           Your Love (D茅j脿 Vu)         NaN  Unknown     19.0
# 1814                     Dreamland         NaN  Unknown     19.0
# 39330                   Dead Horse         NaN  Unknown     19.0
# 39331                       Simmer         NaN  Unknown     19.0
#
# [98340 rows x 22 columns]

# %%
genre_number = dataFrame_full_artist["genre_id"].value_counts()
value = genre_number.values
index = genre_number.index.values
genre_dict = {}
for i in range(len(value)):
    genre_dict[index[i]] = value[i]
    
genre_num = []
for i in range(len(value)):
    genre_num.append([i,genre_dict[i]])
genre_num = np.array(genre_num).T[-1]
genre_position = np.cumsum(genre_num)
print("genre_num = \n", genre_num)
print("genre_position = \n", genre_position)
# Out:
# genre_num =
#  [ 6942   824 47513  1058  6279 10340  1256  1397   710  1460  7608  4674
#   2352  1421   329   243  1332    56   271  2275]
# genre_position =
#  [ 6942  7766 55279 56337 62616 72956 74212 75609 76319 77779 85387 90061
#  92413 93834 94163 94406 95738 95794 96065 98340]

# %% [markdown]
# # Kernel Code
#
# ## Part1: 将整张表格按照流派分成20个文件，标号0~19，最后一个为unknown

# %%
dataFrame_full_artist
# Out:
#                            artist_names        artists_id  danceability  \
# 40098                 ['Hot Lips Page']          [825032]         0.626
# 17637                 ['Bunny Berigan']          [639789]         0.531
# 17638                 ['Bunny Berigan']          [639789]         0.636
# 28638      ['Eddie "Cleanhead" Vinson']          [137137]         0.597
# 39191  ['Harry James', 'Helen Forrest']  [950571, 673360]         0.283
# ...                                 ...               ...           ...
# 20420              ['Childish Gambino']         [2487188]         0.798
# 1811                  ['Glass Animals']         [2984484]         0.854
# 1814                  ['Glass Animals']         [2984484]         0.253
# 39330               ['Hayley Williams']          [364537]         0.737
# 39331               ['Hayley Williams']          [364537]         0.790
#
#        energy  valence    tempo  loudness  mode  key  acousticness  ...  \
# 40098   0.452    0.835  125.293   -12.341     0    7         0.968  ...
# 17637   0.170    0.805  165.165   -14.500     1    5         0.991  ...
# 17638   0.468    0.922  109.831   -12.714     1    5         0.921  ...
# 28638   0.194    0.625   73.699   -11.920     1    5         0.964  ...
# 39191   0.223    0.383   75.249    -9.699     1    0         0.941  ...
# ...       ...      ...      ...       ...   ...  ...           ...  ...
# 20420   0.559    0.604  102.018   -10.868     1    5         0.286  ...
# 1811    0.671    0.631  107.994    -7.158     1    7         0.019  ...
# 1814    0.352    0.099  141.970   -11.509     1    8         0.883  ...
# 39330   0.787    0.590   90.014    -4.587     1    7         0.121  ...
# 39331   0.599    0.362  109.978    -7.417     1    7         0.218  ...
#
#        speechiness  explicit  duration_ms  popularity  year  release_date  \
# 40098       0.0698         0       200067           0  1924          1924
# 17637       0.0771         0       197787          27  1925          1925
# 17638       0.0575         0       188040           6  1926          1926
# 28638       0.0883         0       161067           0  1927          1927
# 39191       0.0304         0       203773           3  1927          1927
# ...            ...       ...          ...         ...   ...           ...
# 20420       0.0592         1       236507          63  2020     3/22/2020
# 1811        0.0543         0       234372          69  2020     2/19/2020
# 1814        0.0357         0       203492          68  2020      5/1/2020
# 39330       0.0525         0       199413          66  2020      5/8/2020
# 39331       0.0431         1       266116          65  2020      5/8/2020
#
#              song_title (censored) Unnamed: 19    genre genre_id
# 40098                 Jump For Joy         NaN     Jazz      0.0
# 17637                        Marie         NaN     Jazz      0.0
# 17638             *********** Rose         NaN     Jazz      0.0
# 28638  When My Baby Left Me - Live         NaN     Jazz      0.0
# 39191  It's Been a Long, Long Time         NaN     Jazz      0.0
# ...                            ...         ...      ...      ...
# 20420                        *****         NaN  Unknown     19.0
# 1811           Your Love (D茅j脿 Vu)         NaN  Unknown     19.0
# 1814                     Dreamland         NaN  Unknown     19.0
# 39330                   Dead Horse         NaN  Unknown     19.0
# 39331                       Simmer         NaN  Unknown     19.0
#
# [98340 rows x 22 columns]

# %%
print(genre_position)
head = 0
range_list = []
genre_num = len(genre_position)
for i in range(genre_num):
    range_list.append([head, genre_position[i]])
    head = genre_position[i]
print(range_list)
# Out:
# [ 6942  7766 55279 56337 62616 72956 74212 75609 76319 77779 85387 90061
#  92413 93834 94163 94406 95738 95794 96065 98340]
# [[0, 6942], [6942, 7766], [7766, 55279], [55279, 56337], [56337, 62616], [62616, 72956], [72956, 74212], [74212, 75609], [75609, 76319], [76319, 77779], [77779, 85387], [85387, 90061], [90061, 92413], [92413, 93834], [93834, 94163], [94163, 94406], [94406, 95738], [95738, 95794], [95794, 96065], [96065, 98340]]

# %%
for genre_idx, genre_range in enumerate(range_list):
    sub_dataFrame = dataFrame_full_artist[genre_range[0]:genre_range[1]]
    sub_dataFrame.to_csv("genre/{}.csv".format(genre_idx))
    

sub_dataFrame = sub_dataFrame.sort_values(by=['genre_id', 'year', 'artists_id'], ascending=True)
sub_dataFrame
# Out:
#                    artist_names artists_id  danceability  energy  valence  \
# 84276  ['The Chenille Sisters']   [762724]         0.581   0.132    0.315
# 84277  ['The Chenille Sisters']   [762724]         0.712   0.312    0.542
# 84278  ['The Chenille Sisters']   [762724]         0.687   0.557    0.809
# 84279  ['The Chenille Sisters']   [762724]         0.657   0.455    0.960
# 84280  ['The Chenille Sisters']   [762724]         0.647   0.587    0.552
# ...                         ...        ...           ...     ...      ...
# 20420      ['Childish Gambino']  [2487188]         0.798   0.559    0.604
# 1811          ['Glass Animals']  [2984484]         0.854   0.671    0.631
# 1814          ['Glass Animals']  [2984484]         0.253   0.352    0.099
# 39330       ['Hayley Williams']   [364537]         0.737   0.787    0.590
# 39331       ['Hayley Williams']   [364537]         0.790   0.599    0.362
#
#          tempo  loudness  mode  key  acousticness  ...  speechiness  explicit  \
# 84276   71.587   -16.464     1   10         0.896  ...       0.0330         0
# 84277   76.981   -11.535     1    8         0.818  ...       0.0552         0
# 84278  121.011   -11.106     1    8         0.671  ...       0.0594         0
# 84279  143.431   -11.877     1   10         0.624  ...       0.0547         0
# 84280  119.703   -10.882     1    5         0.601  ...       0.0638         0
# ...        ...       ...   ...  ...           ...  ...          ...       ...
# 20420  102.018   -10.868     1    5         0.286  ...       0.0592         1
# 1811   107.994    -7.158     1    7         0.019  ...       0.0543         0
# 1814   141.970   -11.509     1    8         0.883  ...       0.0357         0
# 39330   90.014    -4.587     1    7         0.121  ...       0.0525         0
# 39331  109.978    -7.417     1    7         0.218  ...       0.0431         1
#
#        duration_ms  popularity  year  release_date  song_title (censored)  \
# 84276       355440           1  1924          1924    Sentimental Journey
# 84277       133200           1  1924          1924              Low Gravy
# 84278       176533           0  1924          1924     I Want To Be Happy
# 84279       180667           1  1924          1924     **** and Coca Cola
# 84280       313707           0  1924          1924          Bye Bye *****
# ...            ...         ...   ...           ...                    ...
# 20420       236507          63  2020     3/22/2020                  *****
# 1811        234372          69  2020     2/19/2020    Your Love (D茅j脿 Vu)
# 1814        203492          68  2020      5/1/2020              Dreamland
# 39330       199413          66  2020      5/8/2020             Dead Horse
# 39331       266116          65  2020      5/8/2020                 Simmer
#
#       Unnamed: 19    genre genre_id
# 84276         NaN  Unknown     19.0
# 84277         NaN  Unknown     19.0
# 84278         NaN  Unknown     19.0
# 84279         NaN  Unknown     19.0
# 84280         NaN  Unknown     19.0
# ...           ...      ...      ...
# 20420         NaN  Unknown     19.0
# 1811          NaN  Unknown     19.0
# 1814          NaN  Unknown     19.0
# 39330         NaN  Unknown     19.0
# 39331         NaN  Unknown     19.0
#
# [2275 rows x 22 columns]

# %% [markdown]
# ## Part2: 将20个文件按照年份继续细分，注意其间使用了influence加权

# %%
# 见后一个文件
